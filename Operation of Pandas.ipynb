# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
dict_list = [{'id':101, 'name':'Pooja Sharma', 'role': 'ML', 'dob': '2/7/1989', 'age':'23 year', 'sal':98000, 'gen': 'Female', 'addr':'Pune,MH'},
{'id':102, 'name':'Jock Gill', 'role': 'DS', 'dob': '27/7/1990', 'age':'45 year', 'sal':67000, 'gen': 'Male', 'addr':'Nagpur,MH'},
{'id':103, 'name':'Kashish Ahuja', 'role': 'Python Developer', 'dob': '13/4/1989', 'age':'21 year', 'sal':100000, 'gen': 'Male', 'addr':'Bhopal,MP'},
{'id':104, 'name':'Tej Gill', 'role': 'Software Testing', 'dob': '21/2/1985', 'age':'29 year', 'sal':90000, 'gen': 'Female', 'addr':'Shrinagar,J&K'},
{'id':105, 'name':'Justin Disusa', 'role': 'DS', 'dob': '23/4/1989', 'age':'26 year', 'sal':63000, 'gen': 'Male', 'addr':'Raipur,RG'}]

# %%
df = pd.DataFrame(dict_list)

# %%
df
# Out:
#     id           name              role        dob      age     sal     gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000  Female
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    Male
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    Male
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000  Female
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    Male
#
#             addr
# 0        Pune,MH
# 1      Nagpur,MH
# 2      Bhopal,MP
# 3  Shrinagar,J&K
# 4      Raipur,RG

# %%
df.columns
# Out:
# Index(['id', 'name', 'role', 'dob', 'age', 'sal', 'gen', 'addr'], dtype='object')

# %% [markdown]
# ## Access particular Column

# %%
df['name']
# Out:
# 0     Pooja Sharma
# 1        Jock Gill
# 2    Kashish Ahuja
# 3         Tej Gill
# 4    Justin Disusa
# Name: name, dtype: object

# %%
df['role']
# Out:
# 0                  ML
# 1                  DS
# 2    Python Developer
# 3    Software Testing
# 4                  DS
# Name: role, dtype: object

# %%
df['sal']
# Out:
# 0     98000
# 1     67000
# 2    100000
# 3     90000
# 4     63000
# Name: sal, dtype: int64

# %%
## Access multiple Column

# %%
df[['name','sal']]
# Out:
#             name     sal
# 0   Pooja Sharma   98000
# 1      Jock Gill   67000
# 2  Kashish Ahuja  100000
# 3       Tej Gill   90000
# 4  Justin Disusa   63000

# %%
df[['role','age']]
# Out:
#                role      age
# 0                ML  23 year
# 1                DS  45 year
# 2  Python Developer  21 year
# 3  Software Testing  29 year
# 4                DS  26 year

# %%
df1 = df[['name','age','role']]

# %%
df1
# Out:
#             name      age              role
# 0   Pooja Sharma  23 year                ML
# 1      Jock Gill  45 year                DS
# 2  Kashish Ahuja  21 year  Python Developer
# 3       Tej Gill  29 year  Software Testing
# 4  Justin Disusa  26 year                DS

# %%
df
# Out:
#     id           name              role        dob      age     sal     gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000  Female
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    Male
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    Male
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000  Female
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    Male
#
#             addr
# 0        Pune,MH
# 1      Nagpur,MH
# 2      Bhopal,MP
# 3  Shrinagar,J&K
# 4      Raipur,RG

# %% [markdown]
# ## Create new column with existing column

# %%
df['date'] = df['dob'].apply(lambda x: x.split('/')[0])

# %%
df
# Out:
#     id           name              role        dob      age     sal     gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000  Female
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    Male
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    Male
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000  Female
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    Male
#
#             addr date
# 0        Pune,MH    2
# 1      Nagpur,MH   27
# 2      Bhopal,MP   13
# 3  Shrinagar,J&K   21
# 4      Raipur,RG   23

# %%
df['month'] = df['dob'].apply(lambda x: x.split('/')[1])

# %%
df
# Out:
#     id           name              role        dob      age     sal     gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000  Female
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    Male
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    Male
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000  Female
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    Male
#
#             addr date month
# 0        Pune,MH    2     7
# 1      Nagpur,MH   27     7
# 2      Bhopal,MP   13     4
# 3  Shrinagar,J&K   21     2
# 4      Raipur,RG   23     4

# %%
df['year'] = df['dob'].apply(lambda x: x.split('/')[2])

# %%
df
# Out:
#     id           name              role        dob      age     sal     gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000  Female
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    Male
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    Male
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000  Female
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    Male
#
#             addr date month  year
# 0        Pune,MH    2     7  1989
# 1      Nagpur,MH   27     7  1990
# 2      Bhopal,MP   13     4  1989
# 3  Shrinagar,J&K   21     2  1985
# 4      Raipur,RG   23     4  1989

# %%
df['age'] = df['age'].apply(lambda x: x.split(' ')[0])

# %%
df
# Out:
#     id           name              role        dob age     sal     gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23   98000  Female
# 1  102      Jock Gill                DS  27/7/1990  45   67000    Male
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21  100000    Male
# 3  104       Tej Gill  Software Testing  21/2/1985  29   90000  Female
# 4  105  Justin Disusa                DS  23/4/1989  26   63000    Male
#
#             addr date month  year
# 0        Pune,MH    2     7  1989
# 1      Nagpur,MH   27     7  1990
# 2      Bhopal,MP   13     4  1989
# 3  Shrinagar,J&K   21     2  1985
# 4      Raipur,RG   23     4  1989

# %%
df['gen'] = df['age'].map({'Male':0, 'Female':1})

# %%
df
# Out:
#     id           name              role        dob age     sal  gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23   98000  NaN
# 1  102      Jock Gill                DS  27/7/1990  45   67000  NaN
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21  100000  NaN
# 3  104       Tej Gill  Software Testing  21/2/1985  29   90000  NaN
# 4  105  Justin Disusa                DS  23/4/1989  26   63000  NaN
#
#             addr date month  year
# 0        Pune,MH    2     7  1989
# 1      Nagpur,MH   27     7  1990
# 2      Bhopal,MP   13     4  1989
# 3  Shrinagar,J&K   21     2  1985
# 4      Raipur,RG   23     4  1989

# %%
df['gen'] = ['Female','Male','Male','Male','Male']

# %%
df
# Out:
#     id           name              role        dob      age     sal     gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000  Female
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    Male
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    Male
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000    Male
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    Male
#
#             addr date
# 0        Pune,MH    2
# 1      Nagpur,MH   27
# 2      Bhopal,MP   13
# 3  Shrinagar,J&K   21
# 4      Raipur,RG   23

# %%
df['gen'] = df['gen'].map({'Male':0, 'Female':1})

# %%
df
# Out:
#     id           name              role        dob      age     sal  gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000    1
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    0
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    0
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000    0
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    0
#
#             addr date
# 0        Pune,MH    2
# 1      Nagpur,MH   27
# 2      Bhopal,MP   13
# 3  Shrinagar,J&K   21
# 4      Raipur,RG   23

# %%
df['gen'].map({'Male':0, 'Female':1})
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: gen, dtype: int64

# %%
df['First Name'] = df['name'].apply(lambda x: x.split(' ')[0])

# %%
df['Last Name'] = df['name'].apply(lambda x: x.split(' ')[1])

# %%
df
# Out:
#     id           name              role        dob age     sal  gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23   98000    1
# 1  102      Jock Gill                DS  27/7/1990  45   67000    0
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21  100000    0
# 3  104       Tej Gill  Software Testing  21/2/1985  29   90000    0
# 4  105  Justin Disusa                DS  23/4/1989  26   63000    0
#
#             addr date month  year First Name Last Name
# 0        Pune,MH    2     7  1989      Pooja    Sharma
# 1      Nagpur,MH   27     7  1990       Jock      Gill
# 2      Bhopal,MP   13     4  1989    Kashish     Ahuja
# 3  Shrinagar,J&K   21     2  1985        Tej      Gill
# 4      Raipur,RG   23     4  1989     Justin    Disusa

# %%
df1 = df[['id','First Name', 'Last Name', 'role', 'age', 'sal', 'gen', 'addr', 'date', 'month','year']]

# %%
df1
# Out:
#     id First Name Last Name              role age     sal  gen           addr  \
# 0  101      Pooja    Sharma                ML  23   98000    1        Pune,MH
# 1  102       Jock      Gill                DS  45   67000    0      Nagpur,MH
# 2  103    Kashish     Ahuja  Python Developer  21  100000    0      Bhopal,MP
# 3  104        Tej      Gill  Software Testing  29   90000    0  Shrinagar,J&K
# 4  105     Justin    Disusa                DS  26   63000    0      Raipur,RG
#
#   date month  year
# 0    2     7  1989
# 1   27     7  1990
# 2   13     4  1989
# 3   21     2  1985
# 4   23     4  1989

# %%
import datetime

# %%
df1['Last Update'] = datetime.datetime.now()
# Out:
# <ipython-input-35-42728a1682cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Last Update'] = datetime.datetime.now()

# %%
df1['city'] = df1['addr'].apply(lambda x: x.split(',')[0])

# %%
df1['state'] = df1['addr'].apply(lambda x: x.split(',')[1])

# %%
df1
# Out:
#     id First Name Last Name              role age     sal  gen           addr  \
# 0  101      Pooja    Sharma                ML  23   98000    1        Pune,MH
# 1  102       Jock      Gill                DS  45   67000    0      Nagpur,MH
# 2  103    Kashish     Ahuja  Python Developer  21  100000    0      Bhopal,MP
# 3  104        Tej      Gill  Software Testing  29   90000    0  Shrinagar,J&K
# 4  105     Justin    Disusa                DS  26   63000    0      Raipur,RG
#
#   date month  year                Last Update       city state
# 0    2     7  1989 2022-02-23 07:55:08.851738       Pune    MH
# 1   27     7  1990 2022-02-23 07:55:08.851738     Nagpur    MH
# 2   13     4  1989 2022-02-23 07:55:08.851738     Bhopal    MP
# 3   21     2  1985 2022-02-23 07:55:08.851738  Shrinagar   J&K
# 4   23     4  1989 2022-02-23 07:55:08.851738     Raipur    RG

# %% [markdown]
# ## Data type of each column

# %%
df1.dtypes
# Out:
# id                      int64
# First Name             object
# Last Name              object
# role                   object
# age                    object
# sal                     int64
# gen                     int64
# addr                   object
# date                   object
# month                  object
# year                   object
# Last Update    datetime64[ns]
# city                   object
# state                  object
# dtype: object

# %%
df1['Last Updated Date'] = df1['Last Update'].apply(lambda x: x.split(' ')[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-d90f6d600cc5> in <module>
# ----> 1 df1['Last Updated Date'] = df1['Last Update'].apply(lambda x: x.split(' ')[0])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-40-d90f6d600cc5> in <lambda>(x)
# ----> 1 df1['Last Updated Date'] = df1['Last Update'].apply(lambda x: x.split(' ')[0])
#
# AttributeError: 'Timestamp' object has no attribute 'split'

# %% [markdown]
# ## Change datatype of column

# %%
df1['Last Update'] = df1['Last Update'].astype('object')

# %%
df1.dtypes
# Out:
# id              int64
# First Name     object
# Last Name      object
# role           object
# age            object
# sal             int64
# gen             int64
# addr           object
# date           object
# month          object
# year           object
# Last Update    object
# city           object
# state          object
# dtype: object

# %%
df1['Last Updated Date'] = df1['Last Update'].apply(lambda x: x.split(' ')[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-d90f6d600cc5> in <module>
# ----> 1 df1['Last Updated Date'] = df1['Last Update'].apply(lambda x: x.split(' ')[0])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-44-d90f6d600cc5> in <lambda>(x)
# ----> 1 df1['Last Updated Date'] = df1['Last Update'].apply(lambda x: x.split(' ')[0])
#
# AttributeError: 'Timestamp' object has no attribute 'split'

# %%
df1
# Out:
#     id First Name Last Name              role age     sal  gen           addr  \
# 0  101      Pooja    Sharma                ML  23   98000    1        Pune,MH
# 1  102       Jock      Gill                DS  45   67000    0      Nagpur,MH
# 2  103    Kashish     Ahuja  Python Developer  21  100000    0      Bhopal,MP
# 3  104        Tej      Gill  Software Testing  29   90000    0  Shrinagar,J&K
# 4  105     Justin    Disusa                DS  26   63000    0      Raipur,RG
#
#   date month  year                 Last Update       city state
# 0    2     7  1989  2022-02-23 07:55:08.851738       Pune    MH
# 1   27     7  1990  2022-02-23 07:55:08.851738     Nagpur    MH
# 2   13     4  1989  2022-02-23 07:55:08.851738     Bhopal    MP
# 3   21     2  1985  2022-02-23 07:55:08.851738  Shrinagar   J&K
# 4   23     4  1989  2022-02-23 07:55:08.851738     Raipur    RG

# %%
import pandas as pd

# %%
dict_list = [{'id':101, 'name':'Pooja Sharma', 'role': 'ML', 'dob': '2/7/1989', 'age':'23 year', 'sal':98000, 'gen': 'Female', 'addr':'Pune,MH'},
{'id':102, 'name':'Jock Gill', 'role': 'DS', 'dob': '27/7/1990', 'age':'45 year', 'sal':67000, 'gen': 'Male', 'addr':'Nagpur,MH'},
{'id':103, 'name':'Kashish Ahuja', 'role': 'Python Developer', 'dob': '13/4/1989', 'age':'21 year', 'sal':100000, 'gen': 'Male', 'addr':'Bhopal,MP'},
{'id':104, 'name':'Tej Gill', 'role': 'Software Testing', 'dob': '21/2/1985', 'age':'29 year', 'sal':90000, 'gen': 'Female', 'addr':'Shrinagar,J&K'},
{'id':105, 'name':'Justin Disusa', 'role': 'DS', 'dob': '23/4/1989', 'age':'26 year', 'sal':63000, 'gen': 'Male', 'addr':'Raipur,RG'}]

# %%
df = pd.DataFrame(dict_list)

# %%
df
# Out:
#     id           name              role        dob      age     sal     gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000  Female
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    Male
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    Male
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000  Female
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    Male
#
#             addr
# 0        Pune,MH
# 1      Nagpur,MH
# 2      Bhopal,MP
# 3  Shrinagar,J&K
# 4      Raipur,RG

# %% [markdown]
# ## Type of Column is always Series--1D

# %%
type(df['sal'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Delete Column

# %%
# default axis --0, Search gen in rows and if find delete that row
df.drop('gen')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-177d853c68a9> in <module>
#       1 # default axis --0, Search gen in rows and if find delete that row
# ----> 2 df.drop('gen')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
# Inpalce=False return copy but doesnt change the original DataFrame 
df.drop('gen', axis=1)
# Out:
#     id           name              role        dob      age     sal  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000
#
#             addr
# 0        Pune,MH
# 1      Nagpur,MH
# 2      Bhopal,MP
# 3  Shrinagar,J&K
# 4      Raipur,RG

# %%
df
# Out:
#     id           name              role        dob      age     sal     gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000  Female
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    Male
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    Male
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000  Female
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    Male
#
#             addr
# 0        Pune,MH
# 1      Nagpur,MH
# 2      Bhopal,MP
# 3  Shrinagar,J&K
# 4      Raipur,RG

# %%
# Inpalce=True return None but does change the original DataFrame 
df.drop('gen', axis=1, inplace=True)

# %%
df
# Out:
#     id           name              role        dob      age     sal  gen  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000    1
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000    0
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000    0
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000    0
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000    0
#
#             addr date
# 0        Pune,MH    2
# 1      Nagpur,MH   27
# 2      Bhopal,MP   13
# 3  Shrinagar,J&K   21
# 4      Raipur,RG   23

# %%
df.drop(columns=['date','gen'], axis=1)
# Out:
#     id           name              role        dob      age     sal  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000
#
#             addr
# 0        Pune,MH
# 1      Nagpur,MH
# 2      Bhopal,MP
# 3  Shrinagar,J&K
# 4      Raipur,RG

# %%
# Not found in axis
df.drop('ML')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-59b28cfaaa56> in <module>
#       1 # Not found in axis
# ----> 2 df.drop('ML')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %% [markdown]
# ## Delete rows based on condition on a column

# %%
df
# Out:
#     id           name              role        dob      age     sal  \
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000
# 3  104       Tej Gill  Software Testing  21/2/1985  29 year   90000
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000
#
#             addr
# 0        Pune,MH
# 1      Nagpur,MH
# 2      Bhopal,MP
# 3  Shrinagar,J&K
# 4      Raipur,RG

# %%
# not found in axis, give index
df.drop(df['role']=='ML')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-f2a6fe7e2100> in <module>
#       1 # not found in axis, give index
# ----> 2 df.drop(df['role']=='ML')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.drop(df[df['role']=='Software Testing'].index)
# Out:
#     id           name              role        dob      age     sal       addr
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000    Pune,MH
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000  Nagpur,MH
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000  Bhopal,MP
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000  Raipur,RG

# %%
index_name = df[df['role']=='Software Testing'].index
df.drop(index_name, inplace=True)

# %%
df
# Out:
#     id           name              role        dob      age     sal       addr
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000    Pune,MH
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000  Nagpur,MH
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000  Bhopal,MP
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000  Raipur,RG

# %% [markdown]
# ## Find null value

# %%
df.isnull()
# Out:
#       id   name   role    dob    age    sal   addr
# 0  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False

# %% [markdown]
# ## count of null values in each row

# %%
df.isnull()
# Out:
#       id   name   role    dob    age    sal   addr
# 0  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# id      0
# name    0
# role    0
# dob     0
# age     0
# sal     0
# addr    0
# dtype: int64

# %% [markdown]
# ## count of not null values in each row

# %%
df.notnull()
# Out:
#      id  name  role   dob   age   sal  addr
# 0  True  True  True  True  True  True  True
# 1  True  True  True  True  True  True  True
# 2  True  True  True  True  True  True  True
# 4  True  True  True  True  True  True  True

# %%
df.notnull().sum()
# Out:
# id      4
# name    4
# role    4
# dob     4
# age     4
# sal     4
# addr    4
# dtype: int64

# %%
## Find Unique Value

# %%
df
# Out:
#     id           name              role        dob      age     sal       addr
# 0  101   Pooja Sharma                ML   2/7/1989  23 year   98000    Pune,MH
# 1  102      Jock Gill                DS  27/7/1990  45 year   67000  Nagpur,MH
# 2  103  Kashish Ahuja  Python Developer  13/4/1989  21 year  100000  Bhopal,MP
# 4  105  Justin Disusa                DS  23/4/1989  26 year   63000  Raipur,RG

# %%
df['role'].unique()
# Out:
# array(['ML', 'DS', 'Python Developer'], dtype=object)

# %% [markdown]
# ## List of Columns in DataFrame

# %%
df.columns
# Out:
# Index(['id', 'name', 'role', 'dob', 'age', 'sal', 'addr'], dtype='object')

# %% [markdown]
# ## Data type of Column

# %%
df.dtypes
# Out:
# id       int64
# name    object
# role    object
# dob     object
# age     object
# sal      int64
# addr    object
# dtype: object

# %% [markdown]
# ## Drop null value----- dropna()

# %%
df1 = pd.read_csv('null_value.csv')

# %%
df1
# Out:
#     id      name      sal   age       gen  dept        loc
# 0  201    'John'  97000.0  34.0    'Male'  'HR'       'US'
# 1  202   'Marry'  87000.0  25.0  'Female'  'IT'        NaN
# 2  203   'Harry'  54000.0  31.0    'Male'  'DS'     'Pune'
# 3  204  'Danial'  62000.0   NaN  'Female'  'ML'   'Nagpur'
# 4  205  'Justin'  98000.0  35.0       NaN  'AI'   'Mumbai'
# 5  206   'Rossy'      NaN  31.0  'Female'  'DS'  'Chennai'
# 6  207   'Janvi'  89000.0  37.0       NaN  'ML'        NaN
# 7  208       NaN  75000.0  22.0  'Female'  'DS'        NaN

# %%
df1.isnull().sum()
# Out:
# id       0
#  name    1
#  sal     1
#  age     1
#  gen     2
# dept     0
# loc      3
# dtype: int64

# %%
df1.dropna()
# Out:
#     id     name      sal   age     gen  dept     loc
# 0  201   'John'  97000.0  34.0  'Male'  'HR'    'US'
# 2  203  'Harry'  54000.0  31.0  'Male'  'DS'  'Pune'

# %% [markdown]
# ## Drop null values using how

# %%
df1.dropna(how='all')
# Out:
#     id      name      sal   age       gen  dept        loc
# 0  201    'John'  97000.0  34.0    'Male'  'HR'       'US'
# 1  202   'Marry'  87000.0  25.0  'Female'  'IT'        NaN
# 2  203   'Harry'  54000.0  31.0    'Male'  'DS'     'Pune'
# 3  204  'Danial'  62000.0   NaN  'Female'  'ML'   'Nagpur'
# 4  205  'Justin'  98000.0  35.0       NaN  'AI'   'Mumbai'
# 5  206   'Rossy'      NaN  31.0  'Female'  'DS'  'Chennai'
# 6  207   'Janvi'  89000.0  37.0       NaN  'ML'        NaN
# 7  208       NaN  75000.0  22.0  'Female'  'DS'        NaN

# %%
df1.dropna(how='any')
# Out:
#     id     name      sal   age     gen  dept     loc
# 0  201   'John'  97000.0  34.0  'Male'  'HR'    'US'
# 2  203  'Harry'  54000.0  31.0  'Male'  'DS'  'Pune'

# %%
# Perform dropna() on particular column

# %%
df1
# Out:
#     id      name      sal   age       gen  dept        loc
# 0  201    'John'  97000.0  34.0    'Male'  'HR'       'US'
# 1  202   'Marry'  87000.0  25.0  'Female'  'IT'        NaN
# 2  203   'Harry'  54000.0  31.0    'Male'  'DS'     'Pune'
# 3  204  'Danial'  62000.0   NaN  'Female'  'ML'   'Nagpur'
# 4  205  'Justin'  98000.0  35.0       NaN  'AI'   'Mumbai'
# 5  206   'Rossy'      NaN  31.0  'Female'  'DS'  'Chennai'
# 6  207   'Janvi'  89000.0  37.0       NaN  'ML'        NaN
# 7  208       NaN  75000.0  22.0  'Female'  'DS'        NaN

# %%
df1.dropna(how='any',subset=['loc'])
# Out:
#     id      name      sal   age       gen  dept        loc
# 0  201    'John'  97000.0  34.0    'Male'  'HR'       'US'
# 2  203   'Harry'  54000.0  31.0    'Male'  'DS'     'Pune'
# 3  204  'Danial'  62000.0   NaN  'Female'  'ML'   'Nagpur'
# 4  205  'Justin'  98000.0  35.0       NaN  'AI'   'Mumbai'
# 5  206   'Rossy'      NaN  31.0  'Female'  'DS'  'Chennai'

# %%
df1
# Out:
#     id      name      sal   age       gen  dept        loc
# 0  201    'John'  97000.0  34.0    'Male'  'HR'       'US'
# 1  202   'Marry'  87000.0  25.0  'Female'  'IT'        NaN
# 2  203   'Harry'  54000.0  31.0    'Male'  'DS'     'Pune'
# 3  204  'Danial'  62000.0   NaN  'Female'  'ML'   'Nagpur'
# 4  205  'Justin'  98000.0  35.0       NaN  'AI'   'Mumbai'
# 5  206   'Rossy'      NaN  31.0  'Female'  'DS'  'Chennai'
# 6  207   'Janvi'  89000.0  37.0       NaN  'ML'        NaN
# 7  208       NaN  75000.0  22.0  'Female'  'DS'        NaN

# %%
df1.dtypes
# Out:
# id         int64
#  name     object
#  sal     float64
#  age     float64
#  gen      object
# dept      object
# loc       object
# dtype: object

# %%
df1.dropna(subset=['sal'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-1f3b601db7b4> in <module>
# ----> 1 df1.dropna(subset=['sal'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5160             check = indices == -1
#    5161             if check.any():
# -> 5162                 raise KeyError(list(np.compress(check, subset)))
#    5163             agg_obj = self.take(indices, axis=agg_axis)
#    5164
#
# KeyError: ['sal']

# %%
df2
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'      NaN      'Data Analyst'
# 4  105        NaN  91000.0                 NaN

# %%
df2.dropna()
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'

# %%
df2.dropna(subset=['sal'])
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 4  105        NaN  91000.0                 NaN

# %%
df2.dropna(subset=['sal','role'])
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'

# %%
df2
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'      NaN      'Data Analyst'
# 4  105        NaN  91000.0                 NaN

# %%
df2.dropna(axis=1, how='any')
# Out:
#     id
# 0  101
# 1  102
# 2  103
# 3  104
# 4  105

# %%
df2.dropna(axis=1, subset=['role'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-176-fae6a6b5522a> in <module>
# ----> 1 df2.dropna(axis=1, subset=['role'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5160             check = indices == -1
#    5161             if check.any():
# -> 5162                 raise KeyError(list(np.compress(check, subset)))
#    5163             agg_obj = self.take(indices, axis=agg_axis)
#    5164
#
# KeyError: ['role']

# %%
df1.dtypes
# Out:
# id         int64
#  name     object
#  sal     float64
#  age     float64
#  gen      object
# dept      object
# loc       object
# dtype: object

# %%
df1['age'] = df1['age'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-152-3c510fd5ee49> in <module>
# ...

# %% [markdown]
# ## Replace--- Operation on complete DataFrame

# %%
# map---on particular column

# %%
df1
# Out:
#     id      name      sal   age       gen  dept        loc
# 0  201    'John'  97000.0  34.0    'Male'  'HR'       'US'
# 1  202   'Marry'  87000.0  25.0  'Female'  'IT'        NaN
# 2  203   'Harry'  54000.0  31.0    'Male'  'DS'     'Pune'
# 3  204  'Danial'  62000.0   NaN  'Female'  'ML'   'Nagpur'
# 4  205  'Justin'  98000.0  35.0       NaN  'AI'   'Mumbai'
# 5  206   'Rossy'      NaN  31.0  'Female'  'DS'  'Chennai'
# 6  207   'Janvi'  89000.0  37.0       NaN  'ML'        NaN
# 7  208       NaN  75000.0  22.0  'Female'  'DS'        NaN

# %%
import numpy as np

# %%
# df1.replace(np.nan, 0)---we can apply it on particular column with specified values using dict
# df1.fillna(0)-----fill all NaN value in DataFrame with specified value

# works same, when columns are not specified

# %%
df1.replace(np.nan, 0)
# Out:
#     id      name      sal   age       gen  dept        loc
# 0  201    'John'  97000.0  34.0    'Male'  'HR'       'US'
# 1  202   'Marry'  87000.0  25.0  'Female'  'IT'          0
# 2  203   'Harry'  54000.0  31.0    'Male'  'DS'     'Pune'
# 3  204  'Danial'  62000.0   0.0  'Female'  'ML'   'Nagpur'
# 4  205  'Justin'  98000.0  35.0         0  'AI'   'Mumbai'
# 5  206   'Rossy'      0.0  31.0  'Female'  'DS'  'Chennai'
# 6  207   'Janvi'  89000.0  37.0         0  'ML'          0
# 7  208         0  75000.0  22.0  'Female'  'DS'          0

# %%
df1.fillna(0)
# Out:
#     id      name      sal   age       gen  dept        loc
# 0  201    'John'  97000.0  34.0    'Male'  'HR'       'US'
# 1  202   'Marry'  87000.0  25.0  'Female'  'IT'          0
# 2  203   'Harry'  54000.0  31.0    'Male'  'DS'     'Pune'
# 3  204  'Danial'  62000.0   0.0  'Female'  'ML'   'Nagpur'
# 4  205  'Justin'  98000.0  35.0         0  'AI'   'Mumbai'
# 5  206   'Rossy'      0.0  31.0  'Female'  'DS'  'Chennai'
# 6  207   'Janvi'  89000.0  37.0         0  'ML'          0
# 7  208         0  75000.0  22.0  'Female'  'DS'          0

# %%
df1.replace(np.nan,{'loc':'Pune', 'name':'Mayuri', 'gen':'Male'})
# Out:
#     id      name      sal   age       gen  dept        loc
# 0  201    'John'  97000.0  34.0    'Male'  'HR'       'US'
# 1  202   'Marry'  87000.0  25.0  'Female'  'IT'       Pune
# 2  203   'Harry'  54000.0  31.0    'Male'  'DS'     'Pune'
# 3  204  'Danial'  62000.0   NaN  'Female'  'ML'   'Nagpur'
# 4  205  'Justin'  98000.0  35.0       NaN  'AI'   'Mumbai'
# 5  206   'Rossy'      NaN  31.0  'Female'  'DS'  'Chennai'
# 6  207   'Janvi'  89000.0  37.0       NaN  'ML'       Pune
# 7  208       NaN  75000.0  22.0  'Female'  'DS'       Pune

# %%
import pandas as pd

# %%
import numpy as np

# %%
df2 = pd.read_csv('sample_csv.csv')

# %%
df2
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'      NaN      'Data Analyst'
# 4  105        NaN  91000.0                 NaN

# %%
df2.replace(np.nan,{'name':'Mayuri'})
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'      NaN      'Data Analyst'
# 4  105     Mayuri  91000.0                 NaN

# %%
df2.replace(np.nan,{'sal':50000, 'role': 'Developer'} )
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'  50000.0      'Data Analyst'
# 4  105        NaN  91000.0           Developer

# %%
df2
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'      NaN      'Data Analyst'
# 4  105        NaN  91000.0                 NaN

# %%
df2.replace(np.nan,{'sal':50000, 'role': 'Developer'}, inplace=True)

# %%
df2
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'  50000.0      'Data Analyst'
# 4  105        NaN  91000.0           Developer

# %%
df2.replace([np.nan,'Developer',50000],['Bob','Tester',60000])
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'  60000.0      'Data Analyst'
# 4  105        Bob  91000.0              Tester

# %%
df2
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'  50000.0      'Data Analyst'
# 4  105        NaN  91000.0           Developer

# %%
df2.replace(np.nan, {'name':'AI'})
# Out:
#     id       name      sal                role
# 0  101      'Kat'  90000.0                'ML'
# 1  102    'Kevin'  87000.0                'DS'
# 2  103   'Justin'  96000.0  'Python Developer'
# 3  104    'Harry'  50000.0      'Data Analyst'
# 4  105         AI  91000.0           Developer
